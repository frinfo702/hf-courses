# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Virtual display
#       2 from pyvirtualdisplay import Display
# ----> 4 virtual_display = Display(visible=False, size=(1400, 900))
#       5 virtual_display.start()
#
# File ~/src/github.com/frinfo702/hf-courses/.venv/lib/python3.12/site-packages/pyvirtualdisplay/display.py:54, in Display.__init__(self, backend, visible, size, color_depth, bgcolor, use_xauth, retries, extra_args, manage_global_env, **kwargs)
#      51 if not cls:
#      52     raise ValueError("unknown backend: %s" % self._backend)
# ---> 54 self._obj = cls(
#      55     size=size,
#      56     color_depth=color_depth,
#      57     bgcolor=bgcolor,
#      58     retries=retries,
#      59     use_xauth=use_xauth,
#      60     # check_startup=check_startup,
#      61     extra_args=extra_args,
# ...
